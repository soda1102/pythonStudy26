# %%
#if문은 조건문으로 판단하여 참(True), 거짓(False)
#if 조건 :
#   조건이 참일 때 실행하는 문
#elif 조건 :
#      위 조건이 false일때 또 비교하는 조건문
#else :
#       위 조건이 모두 해당하지 않을 때 실행하는 조건문

# 학점 계산용 코드
avg = int(input("평균을 입력하세요 >>>"))
if avg >=90 :
    grade = "A" # 90점 이상이면 A

elif avg >=80 :
    grade = "B"  # 80점 이상이면 B

elif avg >=70 :
    grade = "C"  # 70점 이상이면 C

else:
    grade = "F"

print("귀하의 등급은 " + grade + "입니다.")
# Out:
# 귀하의 등급은 B입니다.

# %%
money = True
if money :
    print("택시를 타고 가라")
else :
    print("걸어가라")
# Out:
# 택시를 타고 가라

# %%
money = 2000
card = True
if money >= 3000 or card :
    print("택시 타고 가라")
else :
    print("걸어가라")
# Out:
# 택시 타고 가라

# %%
pocket = ['paper', 'cellphone', 'money']
if 'money' in pocket :
    print("택시타")
else :
    print("걸어가")
# Out:
# 택시타

# %%
pocket = ['paper', 'cellphone', 'money']
if 'money' in pocket :
    pass
else :
    print("카드 꺼내") #pocket 리스트 안에 money 문자열이 있기 때문에 if 다음 문장인 pass가 수행, 결과는 x

# %%
# while문

prompt = """
1. Add
2. Del
3. List
4. Quit

Enter number : """

# %%
number = 0
while number != 4:
    print(prompt)
    number = int(input())

"""    1. Add
    2. Del
    3. List
    4. Quit


Enter number : """
# Out:
# 1. Add
# 2. Del
# 3. List
# 4. Quit
#
# Enter number :
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 4
#       2 while number != 4:
#       3     print(prompt)
# ----> 4     number = int(input())
#       6 """    1. Add
#       7     2. Del
#       8     3. List
#    (...)     11
#      12 Enter number : """
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ipykernel\kernelbase.py:1396, in Kernel.raw_input(self, prompt)
#    1394     msg = "raw_input was called, but this frontend does not support input requests."
#    1395     raise StdinNotImplementedError(msg)
# -> 1396 return self._input_request(
#    1397     str(prompt),
#    1398     self._get_shell_context_var(self._shell_parent_ident),
#    1399     self.get_parent("shell"),
#    1400     password=False,
#    1401 )
#
# ...

# %%
coffee = 10
money = 300
while money :
    print("돈을 받았으니 커피를 줍니다.")
    coffee = coffee - 1
    print("남은 커피의 양은 %d개 입니다." % coffee)
    if coffee == 0 : # 숫자 계산이기 때문에 ""사용하면 안됨!!!
        print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
        break

# %%
coffee = 10
while True :
    money = int(input("돈을 넣어주세요 : "))
    if money == 300:
        print("커피를 줍니다.")
        coffee = coffee - 1
    elif money > 300 :
        print("거스름돈 %d를 주고 커피를 줍니다." % (money - 300))
        coffee = coffee - 1
    else :
        print("돈을 다시 돌려주고 커피를 주지 않습니다.")
        print("남은 커피의 양은 %d개 입니다." % coffee)
    if coffee == 0 :
        print("커피가 다 떨어졌습니다. 판매를 중지합니다.")
        break

# %%
a = 0
while a < 10:
    a = a + 1
    if a % 2 == 0: continue # a를 2로 나눈 나머지가 0이면 a는 짝수, continue를 썼기 때문에 홀수만 도출
    print(a)

# %%
while True :
    print("Ctrl+c를 눌러야 while문을 빠져나갈 수 있습니다.")

# %%
count = 0
while count <3 :
    print(f"카운트 : {count}")
    count += 1
else :
    print("while문이 정상 종료되었습니다.")

# %%
count = 0
while count < 5:
    if count == 2:
        break
    print(f"카운트 : {count}")
    count += 1
else :
    print("while문이 정상 종료되었습니다.")

# %%
i = 1
while i <=3 :
    j = 1
    while j <=3 :
        print(f"i={i}, j={j}")
        j += 1
    i += 1
# Out:
# i=1, j=1
# i=1, j=2
# i=1, j=3
# i=2, j=1
# i=2, j=2
# i=2, j=3
# i=3, j=1
# i=3, j=2
# i=3, j=3

# %%
# for 문

test_list = ['one', 'two', 'three']
for i in test_list :
    print(i)
# Out:
# one
# two
# three

# %%
marks = [90, 25, 67, 45, 80]

number = 0 # 학생에게 붙여줄 번호
for mark in marks : # 90,25,67,45,80을 순서대로 mark에 대입
    number = number + 1
    if mark >= 60 :
        print("%d번 학생은 합격입니다." % number)
    else :
        print("%d번 학생은 불합격입니다." % number)
# Out:
# 1번 학생은 합격입니다.
# 2번 학생은 불합격입니다.
# 3번 학생은 합격입니다.
# 4번 학생은 불합격입니다.
# 5번 학생은 합격입니다.

# %%
marks = [90, 25, 67, 45, 80]

number = 0
for mark in marks :
    number = number + 1
    if mark < 60 :
        continue
    print("%d번 학생 축하합니다. 합격입니다" % number)
# Out:
# 1번 학생 축하합니다. 합격입니다
# 3번 학생 축하합니다. 합격입니다
# 5번 학생 축하합니다. 합격입니다

# %%
add = 0
for i in range(1,11) :
    add = add + i
print(add)
# Out:
# 55

# %%
marks = [90,25,67,45,80]
for number in range(len(marks)) :
    if marks[number] < 60 :
        continue
    print("%d번 학생 축하합니다. 합격입니다." % (number + 1))
# Out:
# 1번 학생 축하합니다. 합격입니다.
# 3번 학생 축하합니다. 합격입니다.
# 5번 학생 축하합니다. 합격입니다.

# %%
for i in range(2,10) :
    for j in range(1,10) :
        print(i*j, end=" ")
    print('')
# Out:
# 2 4 6 8 10 12 14 16 18
# 3 6 9 12 15 18 21 24 27
# 4 8 12 16 20 24 28 32 36
# 5 10 15 20 25 30 35 40 45
# 6 12 18 24 30 36 42 48 54
# 7 14 21 28 35 42 49 56 63
# 8 16 24 32 40 48 56 64 72
# 9 18 27 36 45 54 63 72 81

# %%
a = [1,2,3,4]
result = []
for num in a:
    result.append(num*3)
print(result)
# Out:
# [3, 6, 9, 12]

# %%
a = [1,2,3,4]
result = [num * 3 for num in a]
print(result)
# Out:
# [3, 6, 9, 12]

# %%
a = [1,2,3,4]
result = [num * 3 for num in a if num % 2 == 0] #나머지가 a를 2로 나눴을때 0인 값에 *3을 해라
print(result)
# Out:
# [6, 12]

# %%
result = [x*y for x in range(2,10)
              for y in range(1,10)]
print(result)
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18, 3, 6, 9, 12, 15, 18, 21, 24, 27, 4, 8, 12, 16, 20, 24, 28, 32, 36, 5, 10, 15, 20, 25, 30, 35, 40, 45, 6, 12, 18, 24, 30, 36, 42, 48, 54, 7, 14, 21, 28, 35, 42, 49, 56, 63, 8, 16, 24, 32, 40, 48, 56, 64, 72, 9, 18, 27, 36, 45, 54, 63, 72, 81]

# %%
for i in range(10) :
    if i == 5 :
        break
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(5) :
    print(i)
else :
    print("for문이 정상 종료되었습니다.")
# Out:
# 0
# 1
# 2
# 3
# 4
# for문이 정상 종료되었습니다.

# %%
fruits = ['apple', 'banana', 'cherry']
for i, fruit in enumerate(fruits) :
    print(f"{i}: {fruit}")
# Out:
# 0: apple
# 1: banana
# 2: cherry

# %%
names = ['홍길동', '김철수', '이영희']
scores = [85,72,98]
for name, score in zip(names, scores) :
    print(f"{name} : {score}점")
# Out:
# 홍길동 : 85점
# 김철수 : 72점
# 이영희 : 98점

# %%
names = ['홍길동', '김철수', '이영희']
korean = [85,72,98]
english = [70,88,65]
for name, kor, eng in zip(names, korean, english) :
    print(f"{name} : 국어 {kor}점, 영어 {eng}점")
# Out:
# 홍길동 : 국어 85점, 영어 70점
# 김철수 : 국어 72점, 영어 88점
# 이영희 : 국어 98점, 영어 65점
